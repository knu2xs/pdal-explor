# %%
import pdal

# %%
# !conda list
# Out:
# # packages in environment at D:\Anaconda3\envs\pdal-explor:
# #
# # Name                    Version                   Build  Channel
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# arcgis                    1.8.3                 py37_1668    esri
# arcgispro                 2.7                           0    esri
# arcpy                     2.7             py37_arcgispro_26810  [arcgispro]  esri
# argon2-cffi               20.1.0           py37hcc03f2d_2    conda-forge
# arrow                     0.17.0           py37hc8dfbb8_1    conda-forge
# asn1crypto                1.4.0              pyh9f0ad1d_0    conda-forge
# atomicwrites              1.4.0              pyh9f0ad1d_0    conda-forge
# attrs                     20.3.0             pyhd3deb0d_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# ...
